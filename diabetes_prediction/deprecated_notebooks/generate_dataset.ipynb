# %% [markdown]
# # Load Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

# %% [markdown]
# # Load Data

# %%
from diabetes_prediction.utils.data.dataloader import *

# %%
data_id = 'family'
family_data = generate_meta_data(data_id)
family_data.to_csv(PATH.family_meta, index=False)

# %%
data_id = 'sample_child'
sample_child_data = generate_meta_data(data_id)
sample_child_data.to_csv(PATH.sample_child_meta, index=False)

# %%
data_id = 'sample_adult'
sample_adult_data = generate_meta_data(data_id)
sample_adult_data.to_csv(PATH.sample_adult_meta, index=False)

# %% [markdown]
# ---

# %%
sample_adult_data
# Out:
#         question_id     NaN   NaN  recode              inst_id  final_id                                                                       description   location value_length                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               options                                                                                                                       keywords
# ...
